# %%
# command mode: blue mode
# edit mode: green 
# command mode -> edit mode : Press enter or you can click using mouse in the cell
# edit mode -> command miie : Press ESC


# Ctrl + Enter can be used to run or execute the whole chunk of code you have written in the cell
# You will see a change in [] when you exit any cell

# Ctrl + enter can execute the code but it will not add or move to the next cell

#while
# shift + enter will execute the code and move to next cell

# %%
print("아빠는울룽불룽")
# Out:
# 아빠는울룽불룽

# %%
# dd can be used to

# %%
# add any cell above this cell, you can use 'a' only when you are in command mode
# add any cell below this cell, you can use 'b' only when you are in command mode

# %% [markdown]
# ## First program

# %% [markdown]
# ### Third program

# %% [markdown]
# # Using Markdown

# %% [markdown]
# # Markdwon

# %% [markdown]
# # Markdowon
