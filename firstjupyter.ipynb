# %% [markdown]
# Connected to Python 3.14.0

# %%
1+1
# Out:
# 2

# %%
print("dkQks울룽불루")
# Out:
# dkQks울룽불루

# %%
# Out:
# Traceback (most recent call last):
#   File "/Users/eunu/.vscode/extensions/ms-python.python-2025.18.0-darwin-arm64/python_files/python_server.py", line 134, in exec_user_input
#     retval = callable_(user_input, user_globals)
#   File "<string>", line 1, in <module>
# NameError: name 'rect' is not defined
