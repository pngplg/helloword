# %%
print("this is my second line..")
# Out:
# this is my second line..

# %%
print("나는귀여워")
# Out:
# 나는귀여워

# %%
print("Now i will learn python")
# Out:
# Now i will learn python

# %%
### The above statements are meant just for first program

# %%
# I have understoods how to write a first program and how to comment and document my code

# %%
# I have understood how to comment
# But now I am providing multiple lines.
# How will I commnet now.

# %% [markdown]
# # addition

# %%
10+4
# Out:
# 14

# %%
10+5+6
# Out:
# 21

# %%
10+3+28437942+485309
# Out:
# 28923264

# %% [markdown]
# # Subtraction

# %%
10-4
# Out:
# 6

# %%
989325-47283-27385
# Out:
# 914657

# %%
# Multiplication

# %%
10
